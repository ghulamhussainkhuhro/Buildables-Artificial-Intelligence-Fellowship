# %% [markdown]
# # Notebook 2  Design prompts for everyday work tasks

# %% [markdown]
# ### Question:
# Write down your to-do list for today or this week.
# Pick one task where ai could help.
#
# ---
#
# ### Answer:
#
# my to do list this week
# - finish abis assignment
# - prepare slides for presentation
# - email sir about project deadline
# - group meeting notes need to arrange
# - revise ppt HCI, infosec, abis
#
# the task i pick: **email sir about project deadline**
#
# ### the prompt i gave to gpt:
#
# write a short polite email to my teacher sir naveen kumar asking if the project deadline can be extended by 2 more days because of technical issues, keep it simple and respectful
#
# ### gpt response:
#
# Subject: Request for Extension of Project Deadline
#
# Dear Sir Naveen Kumar,
#
# I hope you are doing well. I am writing to kindly request an extension of 2 days for submitting the project, as I am currently facing some unexpected technical issues. I would be very grateful if you could allow me this extra time to complete the work properly.
#
# Thank you for your understanding.
#
# Respectfully,
# [Your Name]
#
# ### my edit:
#
# Subject: Request for Extension of Project Deadline
#
# Dear Sir Naveen Kumar,
#
# I hope you are doing well. I am writing to kindly request an extension of 2 days for submitting the project, as I am currently facing some unexpected technical issues. I would be very grateful if you could allow me this extra time to complete the work properly.
#
# Thank you for your understanding.
#
# Respectfully,
# Ghulam Hussain
# 23SW050
# 14/09/2025

# %% [markdown]
# ## Write Emails with Generative AI 📧
#
# ### Question
# Exercise: Try It Yourself ❗
# Think of an email you need to write (e.g., to your team, customers, or a client).
# Use the prompt framework:
# - Persona: Who are you?
# - Context: What’s happening?
# - Task: What do you want the email to do?
# - Specificity: Add tone, format, details.
# Ask your AI tool to draft the email.
# Then, iterate:
# - Change the tone (formal → casual, professional → fun).
# - Adjust the audience.
#
# ---
#
# ### Answer
#
#
# #### Scenario:
# I am founder of TechParast and after mids we will be hosting a Workshop on AI Agents and Bots on Wednesday in Lab 3 of SWE Dept.
#
# ---
#
# ### Step 1: Persona
# "I am the founder of TechParast."
#
# ### Step 2: Context
# "After mid exams, we will be hosting a workshop on AI Agents and Bots."
#
# ### Step 3: Task
# "Write an email inviting SWE students to join the workshop."
#
# ### Step 4: Specificity
# - Tone: Professional yet approachable
# - Length: Short and clear
# - Format: Subject + Body
# - Details:
#    - Date: Wednesday (after mids)
#    - Venue: Lab 3, SWE Department
#    - Topic: AI Agents & Bots Workshop
#
# ---
#
# ### Draft Email (Professional & Friendly)
#
# **Subject:** Invitation – AI Agents & Bots Workshop 🤖✨
#
# **Body:**
# Dear Students,
#
# I’m excited to share that **TechParast** will be hosting a **Workshop on AI Agents and Bots** right after the mid exams.
#
# 📅 Date: Wednesday (after mids)
# 📍 Venue: Lab 3, SWE Department
#
# This will be a hands-on session where you’ll learn how to design and build intelligent agents and automation bots. Don’t miss this opportunity to strengthen your AI skills and explore practical applications!
#
# Looking forward to seeing you all in Lab 3.
#
# Best regards,
# Ghulam Hussain Khuhro
# Founder – TechParast
#
# ---
#
# ### Iteration 1 (Fun & Casual for Students)
#
# **Subject:** Ready to build your first AI Agent? 🚀🤖
#
# **Body:**
# Hey Everyone,
#
# Guess what? After mids, **TechParast** is bringing an **AI Agents & Bots Workshop** to Lab 3 (SWE Dept).
#
# 📅 Wednesday (after mids)
# 📍 Lab 3, SWE Department
#
# We’ll explore how to build smart agents and bots that actually *do stuff* for you. Think of it as giving your laptop a brain! 🧠💻
#
# Bring your curiosity, and let’s make AI fun!
#
# See you there,
# — Team TechParast 🚀
#
# ---
#
# ### Iteration 2 (Formal for Faculty/Executives)
#
# **Subject:** Invitation to AI Agents & Bots Workshop
#
# **Body:**
# Respected Faculty,
#
# On behalf of **TechParast**, I am pleased to announce that we will be conducting a **Workshop on AI Agents and Bots** after the mid examinations.
#
# 📅 Date: Wednesday (after mids)
# 📍 Venue: Lab 3, SWE Department
#
# This session will provide students with practical exposure to AI-driven automation and agent-based systems. We would be honored by your guidance and presence during the event.
#
# Sincerely,
# Ghulam Hussain Khuhro
# Founder – TechParast

# %% [markdown]
# ## Prompt with Personality: Match Gen AI to Your Writing Style 😎
#
# ### Question
# Exercise: Try It Yourself ❗
# Practice Tone & Style Prompting
#
# - Pick a short text you’ve written (an email, a report, or a social post).
# - Rewrite your prompt to specify tone and style.
# - Example: “Make this LinkedIn post sound inspirational, like a TED speaker motivating professionals.”
# - Run it through your tool.
# - Iterate: Ask for a new version in a different tone (funny, formal, academic, casual).
# - Compare the results — which version feels most effective for your audience?
#
# ---
#
# ### Answer
#
#
# #### Scenario:
# I wrote a short announcement about our upcoming **TechParast workshop**.
# Base text:
# "After mids, TechParast will host a workshop on AI Agents and Bots on Wednesday in Lab 3 of SWE Department."
#
# ---
#
# ### Step 1: Specify Tone & Style
#
# **Prompt 1 (Inspirational / TED Speaker Style):**
# "Make this announcement sound inspirational, like a TED speaker motivating professionals."
#
# **Result:**
# "After the mids, TechParast invites you to be part of something transformative. Join us this Wednesday in Lab 3 (SWE Department) for a hands-on workshop on AI Agents and Bots. Together, we’ll explore how the future of intelligence and automation can be built by us, today. Don’t just attend — step into the future."
#
# ---
#
# **Prompt 2 (Casual / Like Talking to a Friend):**
# "Rewrite in a casual, friendly tone, as if I’m inviting friends to hang out."
#
# **Result:**
# "hey guys, after mids we’re doing a chill workshop on AI agents & bots in lab 3 (swe dept) this wednesday. if you’ve ever wanted to see how these things actually work, come hang out. it’ll be fun and not boring promise 😅"
#
# ---
#
# **Prompt 3 (Formal / Academic Style):**
# "Rewrite in a formal, academic style suitable for faculty or research colleagues."
#
# **Result:**
# "Following the mid-term examinations, TechParast will be organizing a workshop on AI Agents and Bots. The session will be conducted on Wednesday in Lab 3 of the Software Engineering Department. The objective of this workshop is to provide participants with a structured understanding of agent-based systems and their applications in contemporary computing."
#
# ---
#
# **Prompt 4 (Funny / Witty Style):**
# "Rewrite in a witty, slightly humorous style with playful wording."
#
# **Result:**
# "Attention humans 🤖: after mids, TechParast is running a workshop in Lab 3 (SWE Dept). Topic: AI Agents & Bots. Basically, we’ll show you how to make your computer do the heavy lifting while you relax. come along or risk being outsmarted by your own laptop. 😉"
#
# ---
#
# ### Reflection
# Each tone changes the audience’s perception:
# - Inspirational → Motivates students & professionals.
# - Casual → Feels friendly and approachable.
# - Formal → Appeals to faculty and serious learners.
# - Funny → Grabs attention and lightens the mood.
#
# ---
#
# 📌 **Key Takeaway**
# Tone and style totally change how a message lands. By being specific and iterating, the same announcement can feel motivational, casual, academic, or witty depending on the audience.

# %% [markdown]
# ## Brainstorming Ideas with Generative AI
#
# ### Question
# Exercises : Try It Yourself ❗
#
# **Exercise 1: Icebreakers**
# Write a prompt asking AI to generate 3 creative icebreakers for a new teammate who loves basketball and photography.
#
# **Exercise 2: Product Launch**
# Imagine you’re launching a new mobile fitness app (it can be any product). Write a prompt to:
# - Define a 6-month launch timeline.
# - Suggest 3 pre-launch buzz ideas.
#
# **Exercise 3: Global Audience Twist**
# Take your product launch prompt and iterate by asking the AI to adjust the ideas for a global audience.
#
# ✅ Reflection Question 💡
# How can you use generative AI to spark new ideas in your own projects or workplace?
#
# ---
#
# ### Answer
#
# #### Exercise 1: Icebreakers
# **Exercise 1: Icebreakers**
# Write a prompt asking AI to generate 3 creative icebreakers for a new teammate who loves basketball and photography.
#
# **Prompt:**
# "I need 3 creative icebreakers for a new teammate who loves basketball and photography. Keep them casual and fun for a team meeting."
#
# **Result:**
# 1. “If you could photograph any famous basketball game in history, which one would it be?”
# 2. “What’s harder: capturing the perfect action shot on the court or nailing a sunset photo?”
# 3. “If our team had a basketball jersey, what would the colors and logo look like?”
#
# ---
#
# #### Exercise 2: Product Launch (Mobile Fitness App)
# **Exercise 2: Product Launch**
# Imagine you’re launching a new mobile fitness app (it can be any product). Write a prompt to:
# - Define a 6-month launch timeline.
# - Suggest 3 pre-launch buzz ideas.
#
# **Prompt:**
# "I’m a marketer launching a new mobile fitness app. Create a 6-month launch timeline and 3 pre-launch buzz ideas."
#
# **Result:**
# **6-Month Timeline:**
# - **Month 1–2:** Market research, teaser posts on social media.
# - **Month 3–4:** Beta testing with early adopters, share testimonials.
# - **Month 5:** Influencer partnerships, countdown campaign.
# - **Month 6:** Official launch + online event with fitness challenges.
#
# **Pre-launch Buzz Ideas:**
# 1. Challenge: “7-day fitness streak” with rewards for participants.
# 2. Behind-the-scenes reels of app features.
# 3. Invite fitness bloggers to review an early version.
#
# ---
#
# #### Exercise 3: Global Audience Twist
# **Exercise 3: Global Audience Twist**
# Take your product launch prompt and iterate by asking the AI to adjust the ideas for a global audience.
#
# **Prompt:**
# "Now refine the fitness app launch ideas to make them suitable for a global audience."
#
# **Result:**
# - Translate teaser posts into multiple languages (English, Spanish, Urdu, Mandarin).
# - Partner with international fitness influencers across YouTube/TikTok.
# - Create culture-specific challenges, e.g., yoga-based challenge in India, football-inspired challenge in Europe, HIIT sessions in the US.
# - Launch app simultaneously across time zones with regional online events.
#
# ---
#
# #### Reflection Question 💡
# **How I can use this myself:**
# I can use brainstorming prompts to speed up planning for my projects. For example, if TechParast is hosting a workshop, I could brainstorm event themes, icebreakers, or a marketing timeline in minutes instead of hours. It helps me collect rough ideas fast and then refine them in my own style.
#
# ---
#
# 📌 **Key Takeaway**
# Strong prompts that include persona + context + task + format help generate useful creative ideas. By iterating, I can adapt the output for local or global contexts and save time in planning.

# %% [markdown]
# ## **Build Tables & Trackers Effortlessly with AI**
#
# ### Exercises: Try It Yourself ❗
#
# ### Exercise 1: Project Tracker
#
# Prompt AI to create a **project tracker** with columns: Task, Owner, Deadline, Status.
# Add constraints: Each owner should have no more than 2 active tasks.
#
# Prompt: create a project tracker with columns: Task, Owner, Deadline, Status.
# Constraint: each owner should have no more than 2 active tasks.
#
# ---
#
# ### Answer
#
# | Task           | Owner | Deadline   | Status   |
# |----------------|-------|------------|----------|
# | Design mockup  | A     | 20 Sept    | Active   |
# | Backend api    | B     | 22 Sept    | Active   |
# | Testing        | A     | 25 Sept    | Pending  |
# | Docs writing   | C     | 26 Sept    | Active   |
# | Deploy setup   | B     | 27 Sept    | Pending  |
#
# check:
# - Owner A → 2 active (ok)
# - Owner B → 1 active (ok)
# - Owner C → 1 active (ok)
# so constraint followed.
#
#
# ### Exercise 2: Event Schedule
#
# You’re planning a **3-day conference**. Ask AI to generate a schedule with:
#
# * Columns: Day, Session Title, Speaker, Time.
# * Constraint: No speaker should have more than 1 session per day.
#
# Prompt: plan 3-day conference with columns: Day, Session Title, Speaker, Time.
# Constraint: no speaker should have more than 1 session per day.
#
# ---
#
# ### Answer
#
# | Day  | Session Title       | Speaker | Time   |
# |------|--------------------|---------|--------|
# | Day 1| Opening keynote    | Dr X    | 9:00am |
# | Day 1| AI & Society talk  | Prof Y  | 11:00am|
# | Day 1| Networking         | Z       | 2:00pm |
# | Day 2| Data ethics panel  | Prof Y  | 10:00am|
# | Day 2| Cloud workshop     | Dr X    | 1:00pm |
# | Day 2| Startup pitches    | Z       | 3:00pm |
# | Day 3| Future tech forum  | Dr X    | 9:00am |
# | Day 3| Closing ceremony   | Prof Y  | 12:00pm|
#
# each speaker appears only once per day → constraint satisfied.
#
# ### Exercise 3: Team Availability
#
# Write a prompt to generate a **vacation tracker** for 8 employees.
#
# * Columns: Employee, Vacation Start, Vacation End.
# * Constraint: At least 5 employees must be available at all times.
#
# Prompt: generate vacation tracker for 8 employees.
# Columns: Employee, Vacation Start, Vacation End.
# Constraint: at least 5 employees must be available at all times.
#
# ---
#
# ### Answer
#
# | Employee | Vacation Start | Vacation End |
# |----------|----------------|--------------|
# | Emp1     | 15 Sept        | 18 Sept      |
# | Emp2     | 16 Sept        | 19 Sept      |
# | Emp3     | 20 Sept        | 22 Sept      |
# | Emp4     | 25 Sept        | 27 Sept      |
# | Emp5     | 15 Sept        | 16 Sept      |
# | Emp6     | 28 Sept        | 30 Sept      |
# | Emp7     | 21 Sept        | 22 Sept      |
# | Emp8     | 29 Sept        | 30 Sept      |
#
# cross checking:
# - never more than 3 away at same time, so always 5+ available.
#
# ### ✅ Reflection Question
#
# How could you use AI to **organize recurring tasks** (like meetings, deadlines, or resources) at your workplace?
#
# honestly i would use it to setup a repeating calendar or sheet. like for weekly team meeting i could just ask it to auto create entries with times + reminders. same for monthly deadlines, like auto generate task lists with due dates. it would save me from rewriting the same stuff again n again. also it can track resources like who booked lab or who is on leave so clashes dont happen.

# %% [markdown]
# ## **Capture Meeting Notes Instantly with AI**
#
# ### Exercises: Try It Yourself ❗
#
# FOR THIS EXECISE I HAVE TAKEN THIS AS MY TRANSCRIPT ITS PSEUDO TRANSCRIPT:
# """
# # Pseudo Meeting Transcript
#
# **Meeting Title:** AI-Powered Project Management Tools – Strategy Discussion
# **Date:** September 14, 2025
# **Attendees:**
# - Sarah (Project Manager)
# - James (AI Engineer)
# - Priya (Data Scientist)
# - Omar (Product Designer)
# - Emily (Operations Lead)
# - David (Intern, Note-taker)
#
# ---
#
# ### Opening Remarks
#
# **Sarah (PM):**
# Good morning, everyone. Thank you for joining today’s strategy session. As you all know, our agenda is to evaluate how AI-powered project management tools can streamline our workflows, especially for task tracking, scheduling, and knowledge sharing. We’ll explore potential integrations, discuss challenges, and assign next steps. Let’s dive right in.
#
# ---
#
# ### Agenda Item 1: Current Pain Points in Project Management
#
# **Sarah (PM):**
# To start, I’d like each of you to briefly share the biggest pain points you face in our current system. Emily, maybe you can kick us off?
#
# **Emily (Ops Lead):**
# Sure. From an operations perspective, my biggest challenge is manual reporting. Every week I consolidate data from Jira, Trello, and sometimes Excel sheets. It’s time-consuming, and I feel like it could easily be automated.
#
# **Omar (Designer):**
# For me, it’s version control of design assets. We use Figma, but when tasks are linked in project trackers, they often don’t reflect the updated file. People sometimes work with outdated designs, leading to confusion.
#
# **Priya (Data Scientist):**
# I’d say knowledge sharing. We’ve built multiple machine learning models, but the documentation is scattered across Google Docs, Notion pages, and Slack threads. Finding the latest experiment results takes more time than running the experiment itself.
#
# **James (AI Engineer):**
# From my side, task dependencies are a nightmare. Our system doesn’t proactively flag when one delayed task is going to affect downstream tasks. We only notice problems when it’s too late.
#
# **Sarah (PM):**
# That’s exactly the kind of input I was hoping for. Thank you, everyone. I think we can all agree the issues revolve around **manual reporting, asset updates, knowledge fragmentation, and dependency management**. Now let’s talk about how AI can help.
#
# ---
#
# ### Agenda Item 2: Exploring AI Solutions
#
# **Sarah (PM):**
# James, since you’re closest to the AI side, could you give us an overview of what’s possible with AI in project management right now?
#
# **James (AI Engineer):**
# Absolutely. AI in project management generally falls into three categories:
#
# 1. **Automation of routine tasks** – for example, auto-generating weekly reports, pulling data from multiple sources, and even drafting meeting summaries.
# 2. **Predictive analytics** – like forecasting project delays based on historical patterns, or estimating how long tasks will actually take compared to what’s planned.
# 3. **Intelligent assistance** – think of chatbots that can answer “Where’s the latest design file?” or “Who owns this task?” by pulling from connected platforms.
#
# There are also tools that use natural language prompts to build schedules or trackers on the fly, which could reduce a lot of manual setup.
#
# **Omar (Designer):**
# That sounds promising. But will it integrate with our current stack? We already use Notion, Jira, Figma, and Slack. I don’t want another standalone tool.
#
# **James (AI Engineer):**
# Good point. Many modern AI project tools have APIs that can integrate directly with existing platforms. For instance, we could connect an AI agent to Jira so that it automatically updates ticket statuses when commits are pushed in GitHub. Similarly, it can fetch the latest Figma links when design tasks are updated.
#
# **Priya (Data Scientist):**
# What about knowledge sharing? Can AI centralize it?
#
# **James (AI Engineer):**
# Yes. Through RAG systems—Retrieval-Augmented Generation—we can connect an LLM to our Notion pages, Slack messages, and Google Drive. That way, instead of searching manually, team members could ask: *“What were the outcomes of Experiment 5?”* and get a summarized, context-aware answer.
#
# **Sarah (PM):**
# That could be a game-changer. Emily, how do you see automation helping your reporting bottleneck?
#
# **Emily (Ops Lead):**
# If AI can pull status updates across Jira and Trello, consolidate them, and present them in a dashboard or even generate a PDF report, it would save me hours every week. I’d only need to review rather than manually compile.
#
# ---
#
# ### Agenda Item 3: Risks and Concerns
#
# **Sarah (PM):**
# This all sounds great, but let’s play devil’s advocate. What risks or concerns should we keep in mind?
#
# **Omar (Designer):**
# My worry is over-automation. Sometimes nuance gets lost in automated updates. For example, if I mark a design as “in progress,” it doesn’t capture whether it’s a rough sketch or a polished draft. If AI blindly reports status, stakeholders might misinterpret progress.
#
# **Priya (Data Scientist):**
# Data privacy is another concern. If we connect Slack and Google Drive, sensitive information might be exposed to the model. We need strict access controls.
#
# **James (AI Engineer):**
# I agree. We’d need role-based permissions and possibly an on-premise or private cloud deployment. Also, AI predictions aren’t always 100% accurate, so we should use them as decision-support, not decision-replacement.
#
# **Emily (Ops Lead):**
# From my side, I’d worry about adoption. If the system feels too complex, people won’t use it, and we’ll end up with another abandoned tool.
#
# **Sarah (PM):**
# All valid points. I suggest we design a **phased rollout**: start with one automation—like Emily’s reporting—and test adoption and accuracy before expanding.
#
# ---
#
# ### Agenda Item 4: Action Plan
#
# **Sarah (PM):**
# Let’s sketch an action plan. James, what do you recommend as our first pilot?
#
# **James (AI Engineer):**
# I’d start with **AI-generated weekly reports**. It’s low risk, measurable in terms of saved hours, and directly useful for Emily. We can integrate Jira and Trello APIs, then have the AI auto-generate a draft report every Friday.
#
# **Emily (Ops Lead):**
# That would be amazing. I can then validate the reports manually for the first few weeks until we trust the system.
#
# **Priya (Data Scientist):**
# In parallel, I’d like to experiment with a **knowledge assistant**. Even if it only indexes Notion at first, it could save us time during model reviews.
#
# **Omar (Designer):**
# And once those are stable, maybe we can look into design asset syncing. It’s not as urgent, but still important.
#
# **Sarah (PM):**
# Perfect. Here’s how I see the next steps:
#
# 1. **AI Weekly Reports Pilot**
#    - Owner: James + Emily
#    - Timeline: Prototype in 3 weeks
#
# 2. **Knowledge Assistant Exploration**
#    - Owner: Priya
#    - Timeline: Initial setup in 4 weeks
#
# 3. **Asset Sync Feasibility Study**
#    - Owner: Omar
#    - Timeline: Research and report in 6 weeks
#
# David, please capture this clearly in the notes.
#
# **David (Intern):**
# Got it, Sarah. Recording everything.
#
# ---
#
# ### Open Floor
#
# **Sarah (PM):**
# Before we wrap, does anyone want to add anything?
#
# **Omar (Designer):**
# Just a small thing: let’s not forget user experience. If we build AI features, they should feel natural, not like extra steps. Maybe we can involve a few non-technical teammates in testing early.
#
# **Emily (Ops Lead):**
# Agreed. Also, let’s think about success metrics. For example, how many hours Emily saves weekly, or how quickly Priya can retrieve knowledge. Otherwise, it’ll be hard to measure impact.
#
# **Priya (Data Scientist):**
# Great point. I’ll set some baseline numbers this week for knowledge search time.
#
# **James (AI Engineer):**
# I’ll also estimate how much time we can save in reporting. That’ll help us build a case for expanding the project later.
#
# ---
#
# ### Closing Remarks
#
# **Sarah (PM):**
# Thanks, everyone. This was a productive discussion. We’ve acknowledged our pain points, explored realistic AI solutions, flagged risks, and created a phased action plan. Let’s reconvene in four weeks to review pilot results. Until then, keep communication open in Slack.
#
# **Meeting Adjourned.**
#
# ---
#
# ### Word Count Approximation
# ~1,020 words
# """
#
#
# ### Exercise 1: Speaker-based Minutes
#
# Take a sample transcript (or your last meeting notes) and prompt AI:
#
# ```
# Summarize the meeting into minutes by speaker.
# Add 2–3 bullet points per speaker, and mark action items clearly.
# ```
# Prompt: group meeting minutes into sections based on topics discussed. for each section, summarize key decisions, and list assigned action items.
#
# ---
#
# ### Answer
#
# # Meeting Minutes – AI-Powered Project Management Tools
#
# **Date:** September 14, 2025
# **Attendees:** Sarah (PM), James (AI Engineer), Priya (Data Scientist), Omar (Designer), Emily (Ops Lead), David (Intern)
#
# ---
#
# ### Sarah (Project Manager)
# - Highlighted need to streamline workflows with AI (reporting, scheduling, knowledge sharing).
# - Facilitated discussion on pain points, risks, and action plans.
# - Proposed **phased rollout** to reduce adoption risks.
#
# **Action Items:**
# - Reconvene in 4 weeks to review pilot results.
# - Ensure action plan responsibilities are tracked.
#
# ---
#
# ### Emily (Operations Lead)
# - Pain point: manual reporting across Jira, Trello, and Excel.
# - Welcomed AI-generated weekly reports to reduce workload.
# - Concern: adoption might fail if system is too complex.
#
# **Action Items:**
# - Validate AI-generated reports manually during the pilot.
# - Provide baseline data on weekly time spent on reporting.
#
# ---
#
# ### Omar (Product Designer)
# - Pain point: outdated design assets cause confusion.
# - Suggested AI syncing of Figma files with trackers.
# - Concerned about over-automation and miscommunication of design status.
#
# **Action Items:**
# - Conduct feasibility study on asset syncing (timeline: 6 weeks).
#
# ---
#
# ### Priya (Data Scientist)
# - Pain point: scattered documentation and knowledge fragmentation.
# - Suggested RAG-based knowledge assistant to centralize info.
# - Flagged data privacy risks when integrating Slack/Drive.
#
# **Action Items:**
# - Set up initial **Knowledge Assistant** indexing Notion (timeline: 4 weeks).
# - Measure baseline knowledge retrieval time.
#
# ---
#
# ### James (AI Engineer)
# - Outlined 3 areas where AI can help: automation, predictive analytics, intelligent assistance.
# - Proposed **AI-generated weekly reports** as the first low-risk pilot.
# - Highlighted risks: accuracy issues, need for role-based access, private deployment.
#
# **Action Items:**
# - Build prototype of AI weekly
#
#
# ### Exercise 2: Action-Focused Notes
#
# Use this prompt:
#
# ```
# Create meeting minutes that focus only on action items.
# Format each entry as: Action Item, Responsible Person, Deadline.
#
# ```
# ### Answer:
#
# # Meeting Minutes – Action Items Only
# **Date:** September 14, 2025
#
# ---
#
# ### Action Items
#
# - **AI Weekly Reports Pilot**
#   - **Responsible:** James (AI Engineer) + Emily (Ops Lead)
#   - **Deadline:** Prototype in 3 weeks
#
# - **Validate AI-Generated Reports**
#   - **Responsible:** Emily (Ops Lead)
#   - **Deadline:** Ongoing during pilot phase
#
# - **Knowledge Assistant Setup (Notion Indexing)**
#   - **Responsible:** Priya (Data Scientist)
#   - **Deadline:** Initial setup in 4 weeks
#
# - **Measure Baseline Knowledge Retrieval Time**
#   - **Responsible:** Priya (Data Scientist)
#   - **Deadline:** Within 1 week
#
# - **Asset Sync Feasibility Study (Figma Integration)**
#   - **Responsible:** Omar (Designer)
#   - **Deadline:** Report in 6 weeks
#
# - **Next Review Meeting**
#   - **Responsible:** Sarah (Project Manager)
#   - **Deadline:** 4 weeks from today
#
#
# ### Exercise 3: Thematic Notes
#
# Try refining for themes:
#
# ```
# Group meeting minutes into sections based on topics discussed.
# For each section, summarize key decisions, and list assigned action items.
# ```
# ### Answer:
# # Meeting Minutes – AI-Powered Project Management Tools
# **Date:** September 14, 2025
# **Attendees:** Sarah (PM), James (AI Engineer), Priya (Data Scientist), Omar (Designer), Emily (Ops Lead), David (Intern)
#
# ---
#
# ## 1. Current Pain Points
# **Key Decisions:**
# - Acknowledge bottlenecks in reporting, design asset updates, knowledge fragmentation, and dependency management.
# - Use these pain points as drivers for AI-powered solutions.
#
# **Action Items:**
# - None (discussion only).
#
# ---
#
# ## 2. Exploring AI Solutions
# **Key Decisions:**
# - AI can help in three areas: automation, predictive analytics, and intelligent assistance.
# - Focus on automation first (low risk, high value).
# - Integration with current tools (Jira, Trello, Figma, Notion, Slack) is essential.
#
# **Action Items:**
# - None (solution exploration).
#
# ---
#
# ## 3. Risks and Concerns
# **Key Decisions:**
# - Over-automation may cause miscommunication.
# - Data privacy must be enforced with role-based permissions.
# - Adoption risk: system must be simple and intuitive.
# - Mitigation: phased rollout starting with one pilot.
#
# **Action Items:**
# - None (risks noted, handled in action plan).
#
# ---
#
# ## 4. Action Plan
# **Key Decisions:**
# - Start with **AI-generated weekly reports** pilot (3 weeks).
# - Parallel setup of **Knowledge Assistant** with limited scope (4 weeks).
# - Conduct **asset sync feasibility study** later (6 weeks).
# - Success metrics: saved hours in reporting, faster knowledge retrieval, reduced confusion in design assets.
#
# **Action Items:**
# - **AI Weekly Reports Pilot** → James + Emily → 3 weeks
# - **Validate AI Reports** → Emily → Ongoing during pilot
# - **Knowledge Assistant Setup (Notion indexing)** → Priya → 4 weeks
# - **Measure baseline knowledge retrieval time** → Priya → 1 week
# - **Asset Sync Feasibility Study (Figma integration)** → Omar → 6 weeks
#
# ---
#
# ## 5. Closing & Next Steps
# **Key Decisions:**
# - Reconvene in 4 weeks to evaluate progress.
# - Early user feedback is important for adoption.
#
# **Action Items:**
# - **Schedule next review meeting** → Sarah → 4 weeks
#
#
# ### ✅ Reflection Question 💡
#
# How could AI-generated meeting notes help you **improve follow-up and accountability** in your workplace?
#
# i think ai notes will help me a lot in followup and accountability coz usually i forget small things from meetings and then have to ask again if ai writes clear action items with names and deadlines it will save time and keep everyone on same page

# %% [markdown]
# ## **Summarize Lengthy Documents with AI**

# %% [markdown]
# ### Exercises: Try It Yourself ❗
#
# ### Exercise 1: Outline Summary
#
# Take a long article or report. Prompt AI:
#
# ### Note❗: used the previous meeting transcript (Strategy Discussion — meeting on Sep 14, 2025) as the source.
#
# ```
# Summarize this document into a bulleted outline of no more than 10 points.
# ```
# ### Answer
#
# - meeting goal: evaluate using smart/automated tools to improve task tracking, scheduling, and knowledge sharing.
# - attendees: sarah (pm), james (engineer), priya (data), omar (design), emily (ops), david (notes).
# - main pain points: manual reporting, outdated design assets, scattered documentation, and missed task dependencies.
# - categories of possible solutions: automation of routine reporting, predictive forecasting for delays, and intelligent query/search over docs.
# - integration note: prefer tools that connect to current stack (notion, jira, figma, slack) via APIs rather than a standalone app.
# - knowledge idea: build an index/search + summarization system that pulls from notion/google drive/slack so people can ask for experiment outcomes quickly.
# - risks: over-automation losing nuance, data/privacy concerns, adoption resistance, and imperfect predictions (use for decision-support).
# - phased plan: pilot weekly automated reports first (low-risk), then explore knowledge indexing, later asset-sync work.
# - owners & timelines: weekly reports → james + emily (prototype in 3 weeks); knowledge assistant → priya (initial in 4 weeks); asset sync study → omar (research in 6 weeks).
# - success checks & next step: measure hours saved, knowledge retrieval time; reconvene in 4 weeks to review pilots.
#
# ### Exercise 2: Audience Summary
#
# Try this with the same text:
#
# ```
# Summarize this document as if explaining it to a high school student.
# ```
#
# ### Answer
#
# we had a team meeting to see how smart tools can make our work easier.
#
# - what's wrong now: people spend too much time making reports, design files get out of date, and docs are scattered so finding results is slow. also some tasks break other tasks because dependencies aren't tracked well.
# - what we thought could help: use automation to pull info from our tools (like jira and figma), make weekly draft reports automatically, and make a searchable system that summarizes notes and experiment results.
# - things to be careful about: automatic stuff can miss detail, and connecting chats/docs to the system could leak private info if not set up right. plus people might not use it if it's complicated.
# - plan: first try auto weekly reports (james + emily will build a prototype in 3 weeks). priya will try a searchable knowledge helper in 4 weeks. omar will study syncing design files in 6 weeks.
# - why it matters: if it works, less busywork, faster answers, and fewer mistakes from using old files.
#
#
# ### Exercise 3: Comparative Summary
#
# Use:
#
# ```
# Summarize this report in two versions:
# 1. Executive summary for leadership.
# 2. Simplified version for frontline employees.
# ```
#
# ### Answer
#
# **1) executive summary (leadership)**
#
# - objective: reduce manual overhead and speed up knowledge retrieval by integrating smart automation into existing tools (notion, jira, figma, slack).
# - recommended approach: phased rollout — pilot automated weekly reporting, then a knowledge-index/search pilot, then asset-sync feasibility study.
# - owners & timelines: weekly reports → james + emily (prototype in 3 weeks); knowledge indexing → priya (initial setup in 4 weeks); asset-sync study → omar (report in 6 weeks).
# - expected benefits: measurable hours saved on reporting, faster access to experiment results, fewer errors from outdated assets — use these metrics to decide expansion.
# - risks & mitigations: privacy and data access (use strict role-based controls / private deployment if needed); accuracy and nuance loss (human review during pilot); adoption risk (keep UX simple, involve non-tech testers early).
# - next step: run the reports pilot, collect baseline metrics (hours spent on reporting, avg search time), review after 4 weeks.
#
# **2) simplified version (frontline employees / team members)**
#
# - tl;dr: we want to try tools that do the boring parts for us — like making weekly reports and finding the right doc faster.
# - what this means for you: you might see auto-draft reports on fridays that you can quickly review instead of making from scratch. you can also ask the new search tool “what happened in experiment 5” and get a short summary.
# - what you need to do: keep your notes and files in the usual places (notion, figma, jira). during pilot, check the auto reports and flag errors so the system improves. join short tests when asked.
# - timeline: reports prototype in 3 weeks, search pilot in 4 weeks, design asset study in ~6 weeks.
# - who to contact: emily for reporting questions, priya for knowledge/search stuff, omar for design asset issues.
# - reassurance: privacy is a priority — access will be controlled, and humans will review automated outputs early on.
#
# markdown
# Copy code
#
#
#
# ### ✅ Reflection Question 💡
#
# How could tailoring summaries to **different audiences** (executives, clients, students) improve understanding and decision-making in your work?
#
# - tailoring summaries to each audience makes information clearer helps executives decide faster builds client trust and supports student learning

# %% [markdown]
# ## **Practice Advanced Summarization Techniques**
#
# ### Key Ideas
#
# * **Chain of Density Prompting**: Start with a broad summary → refine → condense → reach concise, focused insights.
# * Iteration helps **spot hallucinations** and track what gets removed.
# * You can also **expand short outputs** by prompting for more detail.
# * Be **specific about format** (e.g., single sentence, top 3 trends).
#
# ### Exercise
#
# 1. Take a long article or report.
# 2. Summarize it in 3 steps:
#
#    * Broad overview (1 paragraph)
#    * Shorter summary (3 bullet points)
#    * Single sentence (main trend/insight).
#
# ### Answer
#
# **Broad overview (1 paragraph)**
# the team reviewed major pain points in current project workflows — manual reporting, stale design assets, scattered docs, and weak dependency alerts. they discussed using smart automation and document-indexing to reduce manual work, forecast delays, and make information easier to find. concerns about nuance loss, privacy, and adoption were raised, and the group agreed on a phased plan: pilot automated weekly reports (james + emily) then try a searchable knowledge helper (priya) and later study design asset syncing (omar). timelines were set (3–6 weeks) and metrics (hours saved, search time) were requested to judge success.
#
# **Shorter summary (3 bullet points)**
# - pain points: manual reports, outdated designs, fragmented knowledge, dependency blindspots.
# - immediate plan: pilot automated weekly reports → knowledge index/search → asset-sync feasibility (owners & 3–6 week timelines).
# - cautions: protect data access, keep humans in loop for nuance, ensure easy UX to drive adoption.
#
# **Single sentence (main trend/insight)**
# use simple, phased automation connected to current tools to cut busywork and speed up knowledge access, while guarding privacy and adoption.
#
#
# 📌 **Key Takeaway**
#
# Summarization isn’t one-shot—**refinement creates sharper, more reliable outputs**.
